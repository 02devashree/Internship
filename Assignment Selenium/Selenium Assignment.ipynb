# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.shine.com/
# 2. Enter “Data Analyst” in “Job title, Skills” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.shine.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"searchBarInput")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                                Title       Location  \
# 0                             Technical Data Analyst  Bangalore\n+9
# 1  Data Entry Operator(data analyst work) REMOTE ...  Bangalore\n+9
# 2                            Hiring For Data Analyst  Bangalore\n+8
# 3                                Senior Data Analyst  Bangalore\n+8
# 4                                       Data Analyst      Bangalore
# 5                     Mobility Data Analyst - IN/MKR      Bangalore
# 6                                Senior Data Analyst      Bangalore
# 7  hiring for data entry analyst ( position data ...  Bangalore\n+9
# 8                 hiring for data entry analyst work  Bangalore\n+9
# 9  hiring for data entry analyst ( position data ...  Bangalore\n+9
#
#                              Company_name  Experience
# 0  krishna consultancy.. hiring for co...  4 to 9 Yrs
# 1                        prime services..   0 to 1 Yr
# 2        harjai computers private limited  2 to 5 Yrs
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.shine.com/
# 2. Enter “Data Scientist” in “Job title, Skills” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"searchBarInput")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                                Title        Location  \
# 0                                     Data Scientist       Bangalore
# 1                                 SR. DATA SCIENTIST       Bangalore
# 2                 Senior Data Scientist- ML Engineer       Bangalore
# 3                                 Data Scientist III       Bangalore
# 4       Data Scientist Hiring Fresher and Experience  Bangalore\n+17
# 5  Opening for Computer executive, data typing , ...   Bangalore\n+9
# 6                                     Data Scientist   Bangalore\n+6
# 7                         Senior Data Scientist, AWS       Bangalore
# 8  Data Engineer II, Amazon WFM Tech Enterprise Data       Bangalore
# 9                         Data Scientist Recruitment  Bangalore\n+17
#
#                     Company_name    Experience
# 0              the fashion cosmo    0 to 4 Yrs
# 1  te connectivity india pvt ltd    5 to 7 Yrs
# 2              sap india pvt ltd    5 to 7 Yrs
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get the web page https://www.shine.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"searchBarInput")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Delhi/NCR')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_requried=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'')

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 6. Brand
# 7. Product Description
# 8. Price
# The attributes which you have to scrape is ticked marked in the below image.
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data as usual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100sunglasses.
# Note: That all of the above steps have to be done by coding only and not manually.

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"Pke_EE")
designation.send_keys('Sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"_2iLD__")
search.click()

# %%
brand_title=[]
brand_description=[]
brand_price=[]
discount_given=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in title_tags[0:40]:
    title=i.text
    brand_title.append(title)
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"or"IRpwTa _2-ICcC"]')
for i in description_tags[0:40]:
    description=i.text
    brand_description.append(description)
    
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in brand_tags[0:40]:
    price=i.text
    brand_price.append(price)
    
given_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in given_tags[0:40]:
    given=i.text
    discount_given.append(given)

# %%
print(len(brand_title),len(brand_description),len(brand_price),len(discount_given))
# Out:
# 40 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({'Title':brand_title,'Description':brand_description,'Price':brand_price,'Discount':discount_given})
df
# Out:
#              Title                                        Description   Price  \
# 0    VINCENT CHASE                                                       ₹849
# 1    VINCENT CHASE                                       Explore Plus    ₹949
# 2         Fastrack                                              Login    ₹799
# 3         Fastrack                                    Become a Seller    ₹499
# 4        Rich Club                                                       ₹488
# 5         Fastrack                                            Flights    ₹549
# 6          STACTOR                                         Offer Zone    ₹719
# 7        ROYAL SON                   Vogue\nSunglasses | Upto 50% Off    ₹379
# 8           GANSTA                                         Sunglasses    ₹212
# 9         Fastrack                         Need help?\nHelp me decide    ₹849
# 10     Eyewearlabs                                               Home  ₹1,520
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"_1LKTO3")
search.click()

# %%
brand_title=[]
brand_description=[]
brand_price=[]
discount_given=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in title_tags[0:40]:
    title=i.text
    brand_title.append(title)

description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"or"IRpwTa _2-ICcC"]')
for i in description_tags[0:40]:
    description=i.text
    brand_description.append(description)
    
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in brand_tags[0:40]:
    price=i.text
    brand_price.append(price)
    
given_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in given_tags[0:40]:
    given=i.text
    discount_given.append(given)

# %%
print(len(brand_title),len(brand_description),len(brand_price),len(discount_given))
# Out:
# 40 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({'Title':brand_title,'Description':brand_description,'Price':brand_price,'Discount':discount_given})
df
# Out:
#              Title                                        Description   Price  \
# 0    VINCENT CHASE                                                       ₹549
# 1    VINCENT CHASE                                       Explore Plus    ₹849
# 2    VINCENT CHASE                                              Login    ₹849
# 3        CLICKEDIN                                    Become a Seller    ₹199
# 4   ROZZETTA CRAFT                                                       ₹335
# 5            NuVew                                            Flights    ₹278
# 6          DEIXELS                                         Offer Zone    ₹248
# 7           GANSTA                   Vogue\nSunglasses | Upto 50% Off    ₹292
# 8          ROADWAY                                         Sunglasses    ₹398
# 9    VINCENT CHASE                         Need help?\nHelp me decide    ₹679
# 10            IRUS                                               Home    ₹499
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"_1LKTO3")
search.click()

# %%
brand_title=[]
brand_description=[]
brand_price=[]
discount_given=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in title_tags[0:20]:
    title=i.text
    brand_title.append(title)

description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"or"IRpwTa _2-ICcC"]')
for i in description_tags[0:20]:
    description=i.text
    brand_description.append(description)
    
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in brand_tags[0:20]:
    price=i.text
    brand_price.append(price)
    
given_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in given_tags[0:20]:
    given=i.text
    discount_given.append(given)

# %%
print(len(brand_title),len(brand_description),len(brand_price),len(discount_given))
# Out:
# 20 20 20 20

# %%
import pandas as pd
df=pd.DataFrame({'Title':brand_title,'Description':brand_description,'Price':brand_price,'Discount':discount_given})
df
# Out:
#              Title                                     Description   Price  \
# 0    VINCENT CHASE                                                    ₹549
# 1    VINCENT CHASE                                    Explore Plus    ₹849
# 2         Fastrack                                           Login    ₹799
# 3         Fastrack                                 Become a Seller    ₹499
# 4        Rich Club                                                    ₹488
# 5         Fastrack                                         Flights    ₹549
# 6          STACTOR                                      Offer Zone    ₹719
# 7    VINCENT CHASE                Vogue\nSunglasses | Upto 50% Off    ₹949
# 8           GANSTA                                      Sunglasses    ₹212
# 9         Fastrack                      Need help?\nHelp me decide    ₹849
# 10       ROYAL SON                                            Home    ₹379
# ...

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/product- reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market place=FLIPKART
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100reviews.
# Note: All the steps required during scraping should be done through code only and not manually.

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-")

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price
# As shown in the below image, you have to scrape the above attributes.

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"Pke_EE")
designation.send_keys('Sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"_2iLD__")
search.click()

# %%
brand_title=[]
brand_description=[]
brand_price=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in title_tags[0:40]:
    title=i.text
    brand_title.append(title)
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"or"IRpwTa _2-ICcC"]')
for i in description_tags[0:40]:
    description=i.text
    brand_description.append(description)
    
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in brand_tags[0:40]:
    price=i.text
    brand_price.append(price)

# %%
print(len(brand_title),len(brand_description),len(brand_price))
# Out:
# 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({'Title':brand_title,'Description':brand_description,'Price':brand_price})
df
# Out:
#                     Title                                        Description  \
# 0                    aadi
# 1                  MEGPAR                                       Explore Plus
# 2                  BRUTON                                              Login
# 3                   asian
# 4         U.S. POLO ASSN.
# 5                   Sparx                                            Flights
# 6                   asian                                         Offer Zone
# 7               Fuoatieec                                           Footwear
# 8               Deals4you                                   Women's Footwear
# 9                   Sparx                            Kids' & Infant Footwear
# 10                 Footox                                     Men's Footwear
# 11                   ATOM                                               Home
# 12                  Sparx                                           Footwear
# 13                   aadi
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"_1LKTO3")
search.click()

# %%
brand_title=[]
brand_description=[]
brand_price=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in title_tags[0:40]:
    title=i.text
    brand_title.append(title)
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"or"IRpwTa _2-ICcC"]')
for i in description_tags[0:40]:
    description=i.text
    brand_description.append(description)
    
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in brand_tags[0:40]:
    price=i.text
    brand_price.append(price)

# %%
print(len(brand_title),len(brand_description),len(brand_price))
# Out:
# 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({'Title':brand_title,'Description':brand_description,'Price':brand_price})
df
# Out:
#                     Title                                        Description  \
# 0               EZDEZARIO
# 1                LE GREEM                                       Explore Plus
# 2                  ADIDAS                                              Login
# 3                WOODLAND
# 4                WOODLAND
# 5                    aadi                                            Flights
# 6                LE GREEM                                         Offer Zone
# 7                PREKANZO                                           Footwear
# 8         U.S. POLO ASSN.                                   Women's Footwear
# 9                   asian                            Kids' & Infant Footwear
# 10               PREKANZO                                     Men's Footwear
# 11                 Footox                                               Home
# 12                 BRUTON                                           Footwear
# 13                  Arivo
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"_1LKTO3")
search.click()

# %%
brand_title=[]
brand_description=[]
brand_price=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in title_tags[0:20]:
    title=i.text
    brand_title.append(title)

description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"or"IRpwTa _2-ICcC"]')
for i in description_tags[0:20]:
    description=i.text
    brand_description.append(description)
    
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in brand_tags[0:20]:
    price=i.text
    brand_price.append(price)

# %%
print(len(brand_title),len(brand_description),len(brand_price))
# Out:
# 20 20 20

# %%
import pandas as pd
df=pd.DataFrame({'Title':brand_title,'Description':brand_description,'Price':brand_price})
df
# Out:
#            Title                                        Description   Price
# 0         Airson                                                     ₹1,299
# 1      EZDEZARIO                                       Explore Plus    ₹499
# 2          asian                                              Login    ₹646
# 3      EZDEZARIO                                    Become a Seller    ₹494
# 4           PUMA                                                     ₹2,999
# 5   K- FOOTLANCE                                            Flights    ₹349
# 6      EZDEZARIO                                         Offer Zone    ₹494
# 7           ATOM                                           Footwear  ₹1,585
# 8       LE GREEM                                   Women's Footwear    ₹472
# 9     HIGHLANDER                            Kids' & Infant Footwear    ₹870
# 10          LYVI                                     Men's Footwear    ₹295
# ...

# %% [markdown]
# Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” as shown in the below image:
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.amazon.in/")

# %%
designation=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
designation.send_keys('Laptop')

# %%
search=driver.find_element(By.CLASS_NAME,"nav-right")
search.click()

# %%
brand_description=[]
brand_price=[]

# %% [markdown]
# Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpagehttps://www.azquotes.com/
# 2. Click on TopQuotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.azquotes.com/")

# %%
quote_title=[]
quote_author=[]
types_of_quote=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title=i.text
    quote_title.append(title)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    quote_author.append(author)
    
quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_tags[0:100]:
    quote=i.text
    types_of_quote.append(quote)

# %%
print(len(quote_title),len(quote_author),len(types_of_quote))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Title':quote_title,'Author':quote_author,'Types_of_quote':types_of_quote})
df
# Out:
#                                                 Title                Author  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  If you think you are too small to make a diffe...            Dalai Lama
# 98  God doesn't require us to succeed, he only req...         Mother Teresa
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                               Types_of_quote
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"next")
search.click()

# %%
quote_title=[]
quote_author=[]
types_of_quote=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title=i.text
    quote_title.append(title)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    quote_author.append(author)
    
quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_tags[0:100]:
    quote=i.text
    types_of_quote.append(quote)

# %%
print(len(quote_title),len(quote_author),len(types_of_quote))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Title':quote_title,'Author':quote_author,'Types_of_quote':types_of_quote})
df
# Out:
#                                                 Title             Author  \
# 0   Can words describe the fragrance of the very b...    Neltje Blanchan
# 1   Faith is to believe what you do not see; the r...    Saint Augustine
# 2   When everything seems to be going against you,...         Henry Ford
# 3   I have found that if you love life, life will ...  Arthur Rubinstein
# 4   To disarm the people... was the best and most ...       George Mason
# ..                                                ...                ...
# 95  Discipline is the bridge between goals and acc...           Jim Rohn
# 96                   Don't find fault, find a remedy.         Henry Ford
# 97  I used to think the worst thing in life was to...     Robin Williams
# 98  Friends and good manners will carry you where ...    Margaret Walker
# 99  If you want to make a permanent change, stop f...       T. Harv Eker
#
#                            Types_of_quote
# 0                Spring, April, Fragrance
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"next")
search.click()

# %%
quote_title=[]
quote_author=[]
types_of_quote=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title=i.text
    quote_title.append(title)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    quote_author.append(author)
    
quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_tags[0:100]:
    quote=i.text
    types_of_quote.append(quote)

# %%
print(len(quote_title),len(quote_author),len(types_of_quote))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Title':quote_title,'Author':quote_author,'Types_of_quote':types_of_quote})
df
# Out:
#                                                 Title               Author  \
# 0   Success is not final, failure is not fatal: it...    Winston Churchill
# 1   A day of worry is more exhausting than a week ...         John Lubbock
# 2   Strive not to be a success, but rather to be o...      Albert Einstein
# 3   Cancer can take away all of my physical abilit...          Jim Valvano
# 4   Honesty is the first chapter in the book of wi...     Thomas Jefferson
# ..                                                ...                  ...
# 95  Don't watch the clock; do what it does. Keep g...         Sam Levenson
# 96  Don't wait for extraordinary opportunities. Se...  Orison Swett Marden
# 97  If you're not careful, the newspapers will hav...            Malcolm X
# 98  I celebrated Thanksgiving in an old-fashioned ...          Jon Stewart
# 99  One of the things I learned the hard way was t...         Lucille Ball
#
#                            Types_of_quote
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"next")
search.click()

# %%
quote_title=[]
quote_author=[]
types_of_quote=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title=i.text
    quote_title.append(title)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    quote_author.append(author)
    
quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_tags[0:100]:
    quote=i.text
    types_of_quote.append(quote)

# %%
print(len(quote_title),len(quote_author),len(types_of_quote))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Title':quote_title,'Author':quote_author,'Types_of_quote':types_of_quote})
df
# Out:
#                                                 Title                Author  \
# 0   A dress should be tight enough to show you're ...            Edith Head
# 1   Sir, my concern is not whether God is on our s...       Abraham Lincoln
# 2   If you love what you are doing, you will be su...     Albert Schweitzer
# 3   Patience, persistence and perspiration make an...         Napoleon Hill
# 4   Christmas is the season of joy, of holiday gre...  Norman Vincent Peale
# ..                                                ...                   ...
# 95  Risks must be taken because the greatest hazar...         Leo Buscaglia
# 96  He who has never learned to obey cannot be a g...             Aristotle
# 97                         Change before you have to.            Jack Welch
# 98  I don't need a friend who changes when I chang...              Plutarch
# 99  You don't get paid for the hour. You get paid ...              Jim Rohn
#
#                               Types_of_quote
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"next")
search.click()

# %%
quote_title=[]
quote_author=[]
types_of_quote=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title=i.text
    quote_title.append(title)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    quote_author.append(author)
    
quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_tags[0:100]:
    quote=i.text
    types_of_quote.append(quote)

# %%
print(len(quote_title),len(quote_author),len(types_of_quote))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Title':quote_title,'Author':quote_author,'Types_of_quote':types_of_quote})
df
# Out:
#                                                 Title  \
# 0   The only person who is educated is the one who...
# 1   Carry out a random act of kindness, with no ex...
# 2   Don't be afraid to give up the good to go for ...
# 3   Character cannot be developed in ease and quie...
# 4   Honor to the soldier and sailor everywhere, wh...
# ..                                                ...
# 95  Let us not seek the Republican answer or the D...
# 96  Life isn't a matter of milestones, but of mome...
# 97      The time is always right to do what is right.
# 98  Whatever you want to do, do it now. There are ...
# 99  be yourself- not your idea of what you think s...
#
#                      Author                          Types_of_quote
# 0               Carl Rogers  Inspirational, Motivational, Education
# 1            Princess Diana   Inspirational, Motivational, Kindness
# 2       John D. Rockefeller   Inspirational, Motivational, Positive
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"next")
search.click()

# %%
quote_title=[]
quote_author=[]
types_of_quote=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title=i.text
    quote_title.append(title)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    quote_author.append(author)
    
quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_tags[0:100]:
    quote=i.text
    types_of_quote.append(quote)

# %%
print(len(quote_title),len(quote_author),len(types_of_quote))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Title':quote_title,'Author':quote_author,'Types_of_quote':types_of_quote})
df
# Out:
#                                                 Title               Author  \
# 0   If music be the food of love, play on, Give me...  William Shakespeare
# 1   Marriage: If you want something to last foreve...     F. Burton Howard
# 2            Eighty percent of success is showing up.          Woody Allen
# 3   A hero is an ordinary individual who finds the...    Christopher Reeve
# 4   Our dilemma is that we hate change and love it...     Sydney J. Harris
# ..                                                ...                  ...
# 95  There are three constants in life... change, c...        Stephen Covey
# 96             Young people need models, not critics.          John Wooden
# 97  Advice is what we ask for when we already know...           Erica Jong
# 98  The great use of life is to spend it for somet...        William James
# 99  Clear thinking requires courage rather than in...         Thomas Szasz
#
#                            Types_of_quote
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"next")
search.click()

# %%
quote_title=[]
quote_author=[]
types_of_quote=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title=i.text
    quote_title.append(title)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    quote_author.append(author)
    
quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_tags[0:100]:
    quote=i.text
    types_of_quote.append(quote)

# %%
print(len(quote_title),len(quote_author),len(types_of_quote))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Title':quote_title,'Author':quote_author,'Types_of_quote':types_of_quote})
df
# Out:
#                                                 Title              Author  \
# 0   A man is not old until regrets take the place ...      John Barrymore
# 1   A part of kindness consists in loving people m...      Joseph Joubert
# 2   When you start to develop your powers of empat...      Susan Sarandon
# 3   Judge a man by his questions rather than his a...            Voltaire
# 4   If you make a sale, you can make a living. If ...            Jim Rohn
# ..                                                ...                 ...
# 95     All things are difficult before they are easy.       Thomas Fuller
# 96  People ask the difference between a leader and...  Theodore Roosevelt
# 97  The thing that is really hard, and really amaz...       Anna Quindlen
# 98  Love is the ability and willingness to allow t...          Wayne Dyer
# 99  Sooner or later, those who win are those who t...       Paul Tournier
#
#                             Types_of_quote
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"next")
search.click()

# %%
quote_title=[]
quote_author=[]
types_of_quote=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title=i.text
    quote_title.append(title)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    quote_author.append(author)
    
quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_tags[0:100]:
    quote=i.text
    types_of_quote.append(quote)

# %%
print(len(quote_title),len(quote_author),len(types_of_quote))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Title':quote_title,'Author':quote_author,'Types_of_quote':types_of_quote})
df
# Out:
#                                                 Title            Author  \
# 0   Those who matter don't mind, and those who min...    Bernard Baruch
# 1   You were born to win, but to be a winner, you ...        Zig Ziglar
# 2   If you don't like something, change it. If you...      Maya Angelou
# 3   Gratitude unlocks the fullness of life. It tur...    Melody Beattie
# 4   Everyone seems to have a clear idea of how oth...      Paulo Coelho
# ..                                                ...               ...
# 95  America will never be destroyed from the outsi...   Abraham Lincoln
# 96  The average dog is a nicer person than the ave...       Andy Rooney
# 97  Faithful servants never retire. You can retire...       Rick Warren
# 98  In matters of style, swim with the current; in...  Thomas Jefferson
# 99  Dad needs to show an incredible amount of resp...         Tim Allen
#
#                           Types_of_quote
# 0             Inspirational, Funny, Life
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"next")
search.click()

# %%
quote_title=[]
quote_author=[]
types_of_quote=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title=i.text
    quote_title.append(title)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    quote_author.append(author)
    
quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_tags[0:100]:
    quote=i.text
    types_of_quote.append(quote)

# %%
print(len(quote_title),len(quote_author),len(types_of_quote))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Title':quote_title,'Author':quote_author,'Types_of_quote':types_of_quote})
df
# Out:
#                                                 Title                 Author  \
# 0   We are United States Marines, and for two and ...         James L. Jones
# 1                Patience is the companion of wisdom.        Saint Augustine
# 2   I prefer to be true to myself, even at the haz...     Frederick Douglass
# 3   Peace cannot be kept by force; it can only be ...        Albert Einstein
# 4   The two hardest tests on the spiritual road ar...           Paulo Coelho
# ..                                                ...                    ...
# 95  To love means loving the unlovable. To forgive...  Gilbert K. Chesterton
# 96  Be brave. Take risks. Nothing can substitute e...           Paulo Coelho
# 97  If you really want to do something, you'll fin...               Jim Rohn
# 98  It is neither wealth nor splendor; but tranqui...       Thomas Jefferson
# 99  A thousand words will not leave so deep an imp...           Henrik Ibsen
#
#                           Types_of_quote
# ...

# %%
search=driver.find_element(By.CLASS_NAME,"next")
search.click()

# %%
quote_title=[]
quote_author=[]
types_of_quote=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in title_tags[0:100]:
    title=i.text
    quote_title.append(title)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    quote_author.append(author)
    
quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_tags[0:100]:
    quote=i.text
    types_of_quote.append(quote)

# %%
print(len(quote_title),len(quote_author),len(types_of_quote))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Title':quote_title,'Author':quote_author,'Types_of_quote':types_of_quote})
df
# Out:
#                                                 Title                  Author  \
# 0   Courage is the price that life exacts for gran...          Amelia Earhart
# 1   The worst evils which mankind has ever had to ...        Ludwig von Mises
# 2   The moment we begin to fear the opinions of ot...  Elizabeth Cady Stanton
# 3   Trust yourself, you know more than you think y...          Benjamin Spock
# 4   Some people want it to happen, some wish it wo...          Michael Jordan
# ..                                                ...                     ...
# 95  Regret for the things we did can be tempered b...        Sydney J. Harris
# 96  America... just a nation of two hundred millio...      Hunter S. Thompson
# 97  For every disciplined effort there is a multip...                Jim Rohn
# 98  The spiritual journey is individual, highly pe...                Ram Dass
# 99  The mind is not a vessel to be filled but a fi...                Plutarch
#
# ...

# %% [markdown]
# Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,
# Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame.

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.jagranjosh.com/.")

# %%
search=driver.find_element(By.CLASS_NAME,"Header_ham__BUD4g")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div[2]/div[1]/ul/li[6]/a")
search.send_keys('General Knowledge')

# %%
name_title=[]
born_dead_status=[]
term_of_office=[]
remarks=[]

# %%
title_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[3]/table/tbody/tr[2]/td[2]/p/strong/a')
for i in title_tags:
    title=i.text
    name_title.append(title)
    
status_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/spa_n/div[3]/table/tbody/tr[2]/td[3]/p')
for i in status_tags:
    status=i.text
    born_dead_status.append(status)
    
term_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[3]/table/tbody/tr[2]/td[4]')
for i in term_tags:
    term=i.text
    term_of_office.append(term)
    
remarks_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[3]/table/tbody/tr[2]/td[5]')
for i in remarks_tags:
    rem=i.text
    remarks.append(rem)

# %%
print(len(name_title),len(born_dead_status),len(term_of_office),len(remarks))
# Out:
# 1 0 1 1

# %% [markdown]
# Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e.
# Car name and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to type in the search bar ’50 most expensive cars’
# 3. Then click on 50 most expensive carsin the world..
# 4. Then scrap the mentioned data and make the dataframe

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get(" https://www.motor1.com/")

# %%
designation=driver.find_element(By.XPATH,"/html/body/div[10]/div[2]/div/div/div[3]/div/div/button")
designation.send_keys('fifty most expensive cars')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/button[1]")
search.click()

# %%
car_name=[]

# %%
name_tags=driver.find_elements(By.XPATH,'//div[@class="text-box"]')
for i in name_tags[0:24]:
    name=i.text
    car_name.append(name)

# %%
print(len(car_name))
# Out:
# 24

# %%
import pandas as pd 
df=pd.DataFrame({'Name':car_name})
df
# Out:
#                                                  Name
# 0   Used Cars Are Most Expensive In West Palm Beac...
# 1   US Electric Car Prices: Cheapest To Most Expen...
# 2   Most Expensive Dodge Challenger Demon 170 Cost...
# 3   Half Of US New Car Buyers Believe EVs Are Too ...
# 4   This 1996 Nissan Nismo GT-R Is The Most Expens...
# 5   Bentley Performance Cars Line Up For The Most ...
# 6   2023 Corvette Z06 Configurator Now Up, Most Ex...
# 7   Bugatti La Voiture Noire Joins World's Most Ex...
# 8   Most Expensive Auction At Monterey 2022 Is 195...
# 9   Mercedes 300 SLR Uhlenhaut Coupe Is World's Mo...
# 10  Mercedes-Benz 300 SLR Could Be The World's Mos...
# 11  Bentley Coupe By Mulliner Expected To Be Compa...
# 12  50 Most Expensive Cars In The World\nFrom Asto...
# 13  20 Most Expensive Cars to Maintain\nMost of th...
# 14  Koenigsegg Regera And Agera RS With Blue Carbo...
# 15  10 Cars Most Likely To Need An Expensive Head ...
# ...
